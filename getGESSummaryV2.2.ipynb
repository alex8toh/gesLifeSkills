# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('GES2016to2020 AllPolyFGPNSG-LifeSkillsV2.xlsx', '2016-2020 FGPNS - LifeSkills')
df
# Out:
#        Survey Year   Msno Poly Gradtype                             NMC MOE  \
# 0             2020  10002  NYP       FG                            Sciences
# 1             2020  10006  NYP       FG                            Business
# 2             2020  10007  NYP       FG  Information & Digital Technologies
# 3             2020  10009  NYP       FG                Arts, Design & Media
# 4             2020  10011  NYP       FG                Arts, Design & Media
# ...            ...    ...  ...      ...                                 ...
# 74739         2018  54625   TP      PNS                         Engineering
# 74740         2018  54626   TP      PNS                         Engineering
# 74741         2018  54627   TP      PNS                         Engineering
# 74742         2018  54628   TP      PNS                            Business
# 74743         2018  54632   TP      PNS                         Engineering
#
#                                      School School Code  \
# 0        School of Chemical & Life Sciences         SCL
# 1             School of Business Management         SBM
# 2          School of Information Technology         SIT
# 3      School of Interactive & Design Media        SIDM
# 4      School of Interactive & Design Media        SIDM
# ...                                     ...         ...
# 74739                 School of Engineering         ENG
# 74740                 School of Engineering         ENG
# 74741                 School of Engineering         ENG
# 74742                    School of Business         BUS
# 74743                 School of Engineering         ENG
#
#                                            Course Desc Course Code  \
# 0                  Diploma in Food Science & Nutrition      CLDF07
# 1                       Diploma in Business Management      BMDF01
# 2                      Diploma in Business Informatics      ITDF03
# 3                        Diploma in Interaction Design      DMDF09
# 4                        Diploma in Interaction Design      DMDF09
# ...                                                ...         ...
# 74739                 Diploma in Aerospace Engineering         AEG
# 74740                 Diploma in Aerospace Engineering         AEG
# 74741                 Diploma in Aerospace Engineering         AEG
# 74742                     Diploma in Retail Management         RMT
# 74743  Diploma in Biomedical Informatics & Engineering         BIE
#
#       Q23d_aResponse Q23d_bResponse Q23d_cResponse Q23d_dResponse  \
# 0               Well           Well       A little       A little
# 1          Very Well      Very Well      Very Well      Very Well
# 2          Very Well      Very Well      Very Well      Very Well
# 3               Well           Well      Very Well           Well
# 4          Very Well      Very Well      Very Well       A little
# ...              ...            ...            ...            ...
# 74739           Well           Well           Well           Well
# 74740           Well           Well           Well           Well
# 74741           Well           Well           Well           Well
# 74742      Very Well      Very Well      Very Well      Very Well
# 74743           Well           Well           Well           Well
#
#       Q23d_eResponse Q23d_fResponse Q23d_gResponse Q23d_hResponse  \
# 0               Well           Well           Well      Very Well
# 1          Very Well      Very Well      Very Well      Very Well
# 2          Very Well      Very Well      Very Well      Very Well
# 3          Very Well      Very Well      Very Well           Well
# 4               Well           Well       A little           Well
# ...              ...            ...            ...            ...
# 74739      Very Well      Very Well      Very Well      Very Well
# 74740      Very Well           Well      Very Well      Very Well
# 74741           Well           Well           Well           Well
# 74742      Very Well      Very Well      Very Well      Very Well
# 74743           Well           Well           Well           Well
#
#       Q23d_iResponse Q23d_jResponse Q23d_kResponse
# 0               Well      Very Well           Well
# 1          Very Well      Very Well      Very Well
# 2          Very Well      Very Well      Very Well
# 3          Very Well      Very Well           Well
# 4           A little           Well           Well
# ...              ...            ...            ...
# 74739      Very Well      Very Well            NaN
# 74740      Very Well      Very Well            NaN
# 74741           Well           Well            NaN
# 74742       A little       A little            NaN
# 74743           Well           Well            NaN
#
# [74744 rows x 20 columns]

# %%
df.drop(['Msno','NMC MOE', 'School', 'Course Desc'], axis=1, inplace=True)
df
# Out:
#        Survey Year Poly Gradtype School Code Course Code Q23d_aResponse  \
# 0             2020  NYP       FG         SCL      CLDF07           Well
# 1             2020  NYP       FG         SBM      BMDF01      Very Well
# 2             2020  NYP       FG         SIT      ITDF03      Very Well
# 3             2020  NYP       FG        SIDM      DMDF09           Well
# 4             2020  NYP       FG        SIDM      DMDF09      Very Well
# ...            ...  ...      ...         ...         ...            ...
# 74739         2018   TP      PNS         ENG         AEG           Well
# 74740         2018   TP      PNS         ENG         AEG           Well
# 74741         2018   TP      PNS         ENG         AEG           Well
# 74742         2018   TP      PNS         BUS         RMT      Very Well
# 74743         2018   TP      PNS         ENG         BIE           Well
#
#       Q23d_bResponse Q23d_cResponse Q23d_dResponse Q23d_eResponse  \
# 0               Well       A little       A little           Well
# 1          Very Well      Very Well      Very Well      Very Well
# 2          Very Well      Very Well      Very Well      Very Well
# 3               Well      Very Well           Well      Very Well
# 4          Very Well      Very Well       A little           Well
# ...              ...            ...            ...            ...
# 74739           Well           Well           Well      Very Well
# 74740           Well           Well           Well      Very Well
# 74741           Well           Well           Well           Well
# 74742      Very Well      Very Well      Very Well      Very Well
# 74743           Well           Well           Well           Well
#
#       Q23d_fResponse Q23d_gResponse Q23d_hResponse Q23d_iResponse  \
# 0               Well           Well      Very Well           Well
# 1          Very Well      Very Well      Very Well      Very Well
# 2          Very Well      Very Well      Very Well      Very Well
# 3          Very Well      Very Well           Well      Very Well
# 4               Well       A little           Well       A little
# ...              ...            ...            ...            ...
# 74739      Very Well      Very Well      Very Well      Very Well
# 74740           Well      Very Well      Very Well      Very Well
# 74741           Well           Well           Well           Well
# 74742      Very Well      Very Well      Very Well       A little
# 74743           Well           Well           Well           Well
#
#       Q23d_jResponse Q23d_kResponse
# 0          Very Well           Well
# 1          Very Well      Very Well
# 2          Very Well      Very Well
# 3          Very Well           Well
# 4               Well           Well
# ...              ...            ...
# 74739      Very Well            NaN
# 74740      Very Well            NaN
# 74741           Well            NaN
# 74742       A little            NaN
# 74743           Well            NaN
#
# [74744 rows x 16 columns]

# %%
fg_df = df[df['Gradtype'] != 'PNS']
fg_df.drop('Gradtype', axis=1, inplace=True)
fg_df
# Out:
# d:\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        Survey Year Poly School Code Course Code Q23d_aResponse Q23d_bResponse  \
# 0             2020  NYP         SCL      CLDF07           Well           Well
# 1             2020  NYP         SBM      BMDF01      Very Well      Very Well
# 2             2020  NYP         SIT      ITDF03      Very Well      Very Well
# 3             2020  NYP        SIDM      DMDF09           Well           Well
# 4             2020  NYP        SIDM      DMDF09      Very Well      Very Well
# ...            ...  ...         ...         ...            ...            ...
# 73527         2018   TP         BUS         LAW           Well           Well
# 73528         2018   TP         BUS         LAW      Very Well      Very Well
# 73529         2018   TP         ENG         ELN           Well      Very Well
# 73530         2018   TP         ENG         GBS      Very Well           Well
# 73531         2018   TP         ASC         BMS      Very Well      Very Well
#
#       Q23d_cResponse Q23d_dResponse Q23d_eResponse Q23d_fResponse  \
# 0           A little       A little           Well           Well
# 1          Very Well      Very Well      Very Well      Very Well
# 2          Very Well      Very Well      Very Well      Very Well
# 3          Very Well           Well      Very Well      Very Well
# 4          Very Well       A little           Well           Well
# ...              ...            ...            ...            ...
# 73527           Well           Well           Well           Well
# 73528      Very Well      Very Well      Very Well      Very Well
# 73529           Well       A little      Very Well      Very Well
# 73530           Well           Well           Well           Well
# 73531           Well           Well           Well           Well
#
#       Q23d_gResponse Q23d_hResponse Q23d_iResponse Q23d_jResponse  \
# 0               Well      Very Well           Well      Very Well
# 1          Very Well      Very Well      Very Well      Very Well
# 2          Very Well      Very Well      Very Well      Very Well
# 3          Very Well           Well      Very Well      Very Well
# 4           A little           Well       A little           Well
# ...              ...            ...            ...            ...
# 73527           Well           Well           Well           Well
# 73528           Well      Very Well      Very Well      Very Well
# 73529      Very Well      Very Well           Well           Well
# 73530           Well      Very Well      Very Well      Very Well
# 73531           Well      Very Well      Very Well           Well
#
#       Q23d_kResponse
# 0               Well
# 1          Very Well
# 2          Very Well
# 3               Well
# 4               Well
# ...              ...
# 73527            NaN
# 73528            NaN
# 73529            NaN
# 73530            NaN
# 73531            NaN
#
# [47653 rows x 15 columns]

# %%
def calResponseResult(df):

    all_results = df.groupby(["Survey Year", "Poly"])

    response_columns = ['Q23d_aResponse','Q23d_bResponse', 'Q23d_cResponse', 'Q23d_eResponse', \
                        'Q23d_fResponse', 'Q23d_gResponse', 'Q23d_hResponse', 'Q23d_iResponse', \
                        'Q23d_jResponse', 'Q23d_kResponse']
    column_names = ['Year', 'Poly'] 
    column_names.extend(response_columns)
    response_results = pd.DataFrame(columns=column_names)

    for yearpoly, gr in all_results:
        year = yearpoly[0]
        poly = yearpoly[1]
        response_dict = {'Year' : year, 'Poly' : poly}

        for response in response_columns:
            nW  = (gr[response] == "Well").sum()
            nVW = (gr[response] == "Very Well").sum()
            total = len(gr)
            percent = ((nW+nVW)/(total))*100
            response_dict[response] = round(percent,1)
        response_results = response_results.append(response_dict,ignore_index=True)

    return response_results

# %%
def calAllPolyResponseResult(df):

    all_results = df.groupby(["Survey Year"])

    response_columns = ['Q23d_aResponse','Q23d_bResponse', 'Q23d_cResponse', 'Q23d_eResponse', \
                        'Q23d_fResponse', 'Q23d_gResponse', 'Q23d_hResponse', 'Q23d_iResponse', \
                        'Q23d_jResponse', 'Q23d_kResponse']
    
    column_names = ['Year'] 
    column_names.extend(response_columns)
    response_results = pd.DataFrame(columns=column_names)

    for year, gr in all_results:
        response_dict = {'Year' : year}

        for response in response_columns:
            nW  = (gr[response] == "Well").sum()
            nVW = (gr[response] == "Very Well").sum()
            total = len(gr)
            percent = ((nW+nVW)/(total))*100
            response_dict[response] = round(percent,1)
        response_results = response_results.append(response_dict,ignore_index=True)

    # dunno why the year chg to float, force it as int     
    response_results.Year = response_results.Year.astype(int)
    return response_results

# %%
fg_allpoly_response_results = calAllPolyResponseResult(fg_df)
fg_allpoly_response_results
# Out:
#    Year  Q23d_aResponse  Q23d_bResponse  Q23d_cResponse  Q23d_eResponse  \
# 0  2016            88.8            94.1            92.1            90.5
# 1  2017            89.6            93.2            91.7            89.4
# 2  2018            87.8            91.7            91.8            88.5
# 3  2019            88.6            92.4            91.5            88.9
# 4  2020            88.4            92.6            93.2            92.3
#
#    Q23d_fResponse  Q23d_gResponse  Q23d_hResponse  Q23d_iResponse  \
# 0            93.0            83.5            94.5            96.6
# 1            91.6            82.5            94.0            96.0
# 2            90.1            81.6            94.7            95.8
# 3            90.5            82.4            94.7            95.7
# 4            92.9            86.7            96.0            96.6
#
#    Q23d_jResponse  Q23d_kResponse
# 0            95.3             0.0
# 1            95.0             0.0
# 2            94.5             0.0
# 3            94.1            89.5
# 4            95.4            91.7

# %%
response_columns = ['Q23d_aResponse','Q23d_bResponse', 'Q23d_cResponse', 'Q23d_eResponse', \
                    'Q23d_fResponse', 'Q23d_gResponse', 'Q23d_hResponse', 'Q23d_iResponse', \
                    'Q23d_jResponse']
    
for col in response_columns:
    plt.plot(fg_allpoly_response_results.Year, fg_allpoly_response_results[col])

# %%
# import plotly.express as px

# figure = px.line(fg_allpoly_response_results.Year, fg_allpoly_response_results.Q23d_bResponse)
# figure.show()
# Too bad ... plotly is not installed on staff laptop

# %%
writer = pd.ExcelWriter('fg_allpoly_gesLifeskills.xlsx')
fg_allpoly_response_results.to_excel(writer, index=False)
writer.save()

# %%
fg_response_results = calResponseResult(fg_df)

fg_response_results
# Out:
#     Year Poly  Q23d_aResponse  Q23d_bResponse  Q23d_cResponse  Q23d_eResponse  \
# 0   2016   NP            91.5            94.4            91.8            92.1
# 1   2016  NYP            86.9            92.1            92.0            89.9
# 2   2016   RP            90.1            95.7            93.5            88.3
# 3   2016   SP            85.3            94.4            90.1            90.1
# 4   2016   TP            90.1            94.3            92.7            92.0
# 5   2017   NP            91.0            93.6            92.4            90.9
# 6   2017  NYP            87.4            91.7            91.4            88.9
# 7   2017   RP            90.6            94.1            92.4            87.7
# 8   2017   SP            88.5            93.3            90.9            89.4
# 9   2017   TP            90.9            93.6            91.1            90.2
# 10  2018   NP            89.3            91.9            91.4            88.9
# 11  2018  NYP            87.0            90.6            92.5            89.5
# 12  2018   RP            87.2            92.9            91.9            86.1
# 13  2018   SP            85.9            91.7            92.2            89.4
# 14  2018   TP            89.4            91.6            90.9            88.5
# 15  2019   NP            90.1            92.6            91.2            90.0
# 16  2019  NYP            87.4            91.0            91.1            88.5
# 17  2019   RP            90.3            94.7            93.5            87.9
# 18  2019   SP            84.7            90.9            89.9            87.2
# 19  2019   TP            90.4            93.1            91.6            90.7
# 20  2020   NP            90.1            93.4            92.0            92.8
# 21  2020  NYP            88.8            91.7            94.3            93.4
# 22  2020   RP            89.6            94.2            94.5            90.4
# 23  2020   SP            83.7            91.0            92.3            91.3
# 24  2020   TP            89.2            92.5            92.7            93.1
#
#     Q23d_fResponse  Q23d_gResponse  Q23d_hResponse  Q23d_iResponse  \
# 0             93.1            81.6            94.3            96.6
# 1             91.9            86.0            95.2            95.8
# 2             94.1            85.4            94.5            97.1
# 3             92.6            80.7            93.4            96.7
# 4             93.7            82.8            94.4            97.3
# 5             91.5            80.7            94.4            96.1
# 6             90.9            84.7            94.1            95.6
# 7             92.4            83.8            93.7            96.7
# 8             91.1            80.5            93.6            96.0
# 9             92.1            81.8            94.2            96.0
# 10            89.0            80.2            94.4            95.3
# 11            90.6            83.1            95.4            96.1
# 12            91.3            82.8            94.4            95.8
# 13            90.3            81.0            94.4            96.3
# 14            89.2            80.8            94.8            95.3
# 15            90.3            83.0            95.0            96.1
# 16            89.5            82.3            94.6            95.0
# 17            92.4            84.5            94.8            96.5
# 18            89.3            79.1            93.9            94.8
# 19            91.3            82.9            95.0            96.1
# 20            92.4            86.1            95.9            96.7
# 21            94.2            88.1            96.4            96.4
# 22            93.1            86.9            95.8            97.3
# 23            91.5            85.0            95.5            95.9
# 24            93.0            87.0            96.0            96.8
#
#     Q23d_jResponse  Q23d_kResponse
# 0             96.0             0.0
# 1             94.7             0.0
# 2             96.2             0.0
# 3             93.8             0.0
# 4             95.7             0.0
# 5             95.2             0.0
# 6             94.9             0.0
# 7             94.5             0.0
# 8             95.2             0.0
# 9             95.2             0.0
# 10            94.2             0.0
# 11            95.3             0.0
# 12            94.0             0.0
# 13            95.9             0.0
# 14            93.5             0.0
# 15            93.8            90.0
# 16            94.3            90.5
# 17            94.9            88.9
# 18            92.0            87.3
# 19            95.3            90.2
# 20            95.3            91.3
# 21            96.2            93.0
# 22            94.9            92.0
# 23            94.7            90.6
# 24            95.7            91.3

# %%
plt.plot(fg_allpoly_response_results.Year, fg_allpoly_response_results.Q23d_bResponse, color='black')

x = range(2016,2021)
nyp_responses_df = fg_response_results[fg_response_results.Poly=='NYP']
y = [nyp_responses_df['Q23d_bResponse'][nyp_responses_df.Year==year] for year in x ]
plt.plot(x,y, color='blue')

# %%
writer = pd.ExcelWriter('fg_poly_gesLifeskills.xlsx')
fg_response_results.to_excel(writer, index=False)
writer.save()

# %%
pns_df = df[df['Gradtype'] == 'PNS']
pns_df.drop('Gradtype', axis=1, inplace=True)
pns_df

# %%
pns_response_results = calResponseResult(pns_df)

pns_response_results

# %%
writer = pd.ExcelWriter('pns_poly_gesLifeskills.xlsx')
pns_response_results.to_excel(writer, index=False)
writer.save()

# %%
pns_allpoly_response_results = calAllPolyResponseResult(pns_df)
pns_allpoly_response_results

# %%
writer = pd.ExcelWriter('pns_allpoly_gesLifeskills.xlsx')
pns_allpoly_response_results.to_excel(writer, index=False)
writer.save()
